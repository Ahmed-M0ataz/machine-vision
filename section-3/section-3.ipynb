# %%
import cv2

# %%
image = cv2.imread("../DATA/00-puppy.jpg")

# %%
image.shape
# Out:
# (1300, 1950, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
red green blue
image.shape
# Out:
# (1300, 1950, 3)

# %%
# blue green red
# Out:
#   Cell In[18], line 1
#     blue green red
#          ^
# SyntaxError: invalid syntax

# %%
temp_image = image.copy()

# %%
plt.imshow(temp_image)

# %%
image[:,:,0].shape
# Out:
# (1300, 1950)

# %%
image.shape
# Out:
# (1300, 1950, 3)

# %%
image[:,:,0] = temp_image[:,:,2]

# %%
plt.imshow(image)

# %%
image[:,:,2] = temp_image[:,:,0]

# %%
plt.imshow(image)

# %%
image = cv2.imread("../DATA/00-puppy.jpg")

# %%
plt.imshow(image)

# %%
fixed_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_image)

# %%
image.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(cv2.resize(fixed_image,(1200,1200)))

# %%
cv2.resize(fixed_image,(1200,1200)).shape
# Out:
# (1200, 1200, 3)

# %%
import numpy as np

# %%
black_image = np.zeros((500,500,3))

# %%
black_image.max()
# Out:
# 0.0

# %%
plt.imshow(black_image)

# %%
rect_image= cv2.rectangle(black_image,(5,5),(100,100),(0,255,0),10)

# %%
plt.imshow(rect_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(black_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(cv2.circle(black_image,(250,250),100,(255,0,0),10))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
black_image.shape[0]
# Out:
# 500

# %%
plt.imshow(cv2.line(black_image,(0,0),(black_image.shape[0],black_image.shape[1]),(255,0,0),10))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
black_image = np.zeros((800,800,3))

# %%
black_image.shape
# Out:
# (800, 800, 3)

# %%
plt.imshow(cv2.line(black_image,(0,0),(black_image.shape[0],black_image.shape[1]),(255,0,0),10))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image = cv2.imread("../DATA/00-puppy.jpg")

# %%
import cv2

# %%
cv2.imshow("myImage",image)
cv2.waitKey()
# Out:
# -1

# %%
img1 = cv2.imread("../DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread("../DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
one_pixel = first_pixel 0.5 + first_pixel_sec_image * 0.5

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img1 = cv2.resize(img1,(800,800))

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img2 = cv2.resize(img2,(800,800))

# %%
blended_image = cv2.addWeighted(img1,0.9,img2,0.1,0)

# %%
plt.imshow(blended_image)

# %%
img1.shape
# Out:
# (800, 800, 3)

# %%
img2 = cv2.resize(img2,(400,400))

# %%
plt.imshow(img1[0:400,0:400,:])

# %%
blended_image = cv2.addWeighted(img1[0:400,0:400,:],0.9,img2,0.1,0)

# %%
plt.imshow(blended_image)

# %%
img1.shape
# Out:
# (800, 800, 3)

# %%
img1[0:400,0:400,:] = blended_image

# %%
img1.shape
# Out:
# (800, 800, 3)

# %%
plt.imshow(img1)

# %% [markdown]
# # import image
# plot plt

# %%
resize -> 500 500

# %%
improt image 2 resize 500 500

# %%
blending

# %% [markdown]
# black image with np
#
# line
# circle
# rectangular

# %%
blending with deffirant sizes
